# %% [markdown]
# ## pandas
# pandasは表計算ライブラリです。
#
# 公式ドキュメントURL
#
# https://pandas.pydata.org/pandas-docs/version/0.22/
#
# pandasの保持するデータ構造は「データフレーム」である（因みにNumpyは行列）
#
# データフレームとはいわゆる下記のような「表形式」を指します
#
# |　|姓|名|
# |:--|--:|--:|
# |1|ビート|たけし|
# |2|明石家|さんま|
# |3|島田|紳助|
#
# 姓名と書かれている部分がcolumn(列名)
#
# 1,2,3と書かれている部分がindex(行名)と言われます

# %% [markdown]
# # DF生成

# %%
"""読み込み
pandasはNumpyと共に使用されることが多いので、Numpyも読み込んでおきます
"""
import pandas as pd
import numpy as np

# %%
"""DF生成法1
columns,indexのデフォルトは、0から始まる連番
"""
df = pd.DataFrame([
        ["ビート","たけし"],
        ["明石家","さんま"],
        ["島田","紳助"]
    ])
df
# Out:
#      0    1
# 0  ビート  たけし
# 1  明石家  さんま
# 2   島田   紳助

# %%
"""DF生成法2
"""
df = pd.DataFrame(
    [
        ["ビート","たけし"],
        ["明石家","さんま"],
        ["島田","紳助"]
    ]
    ,index=["No1","No2","No3"]
    ,columns=["姓","名"]
)
df
# Out:
#        姓    名
# No1  ビート  たけし
# No2  明石家  さんま
# No3   島田   紳助

# %%
"""DF生成法3
"""
df = pd.DataFrame(
    {
        "姓":["ビート","明石家","島田"],
        "名":["たけし","さんま","紳助"]
    },index=["No1","No2","No3"]
)
df
# Out:
#        姓    名
# No1  ビート  たけし
# No2  明石家  さんま
# No3   島田   紳助

# %% [markdown]
# # DFへのアクセス

# %%
"""データフレーム情報取得
通常はnumpyと共に使用されることが多いので、ここでは、numpyを用いてデータフレーム内の値を生成しています
"""
df = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(100)),
    "国語の点数":np.random.randint(40,100,(100)),
    "英語の点数":np.random.randint(40,100,(100)),
})
df
# Out:
#     数学の点数  国語の点数  英語の点数
# 0      90     42     88
# 1      40     92     40
# 2      54     61     93
# 3      61     99     70
# 4      78     97     56
# 5      48     74     59
# 6      58     71     51
# 7      80     67     84
# 8      65     62     90
# 9      69     60     88
# 10     63     65     86
# 11     61     83     92
# 12     51     54     62
# 13     94     60     55
# 14     98     82     42
# 15     88     54     80
# 16     98     78     46
# 17     87     58     93
# 18     54     88     42
# 19     49     62     55
# 20     92     73     47
# 21     84     64     88
# 22     42     82     86
# 23     90     67     50
# 24     90     94     52
# 25     77     99     56
# 26     79     57     71
# 27     60     45     87
# 28     67     66     73
# 29     88     47     94
# ..    ...    ...    ...
# 70     91     53     86
# 71     64     69     46
# 72     80     68     79
# 73     66     93     75
# 74     91     47     59
# 75     85     98     63
# 76     70     55     88
# 77     50     63     90
# 78     94     74     60
# 79     84     58     65
# 80     76     54     92
# 81     57     59     85
# 82     40     59     45
# 83     41     95     42
# 84     95     77     78
# 85     43     47     72
# 86     90     89     93
# 87     56     92     74
# 88     70     41     78
# 89     88     99     40
# 90     68     82     74
# 91     94     45     49
# 92     60     99     62
# 93     99     49     82
# 94     79     46     73
# 95     67     76     75
# 96     55     99     75
# 97     87     44     41
# 98     51     71     76
# 99     52     68     89
#
# [100 rows x 3 columns]

# %%
"""先頭5行取得
"""
df.head()
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     90     42     88
# 1     40     92     40
# 2     54     61     93
# 3     61     99     70
# 4     78     97     56

# %%
"""末尾の5行
"""
df.tail()
# Out:
#     数学の点数  国語の点数  英語の点数
# 95     67     76     75
# 96     55     99     75
# 97     87     44     41
# 98     51     71     76
# 99     52     68     89

# %%
"""統計量の取得
"""
df.describe()
# Out:
#             数学の点数       国語の点数       英語の点数
# count  100.000000  100.000000  100.000000
# mean    71.500000   69.500000   68.050000
# std     16.999406   17.134347   17.472272
# min     40.000000   40.000000   40.000000
# 25%     56.000000   55.750000   51.750000
# 50%     70.500000   68.500000   68.500000
# 75%     87.250000   82.250000   86.000000
# max     99.000000   99.000000   96.000000

# %%
"""カラムの定義
"""
df.columns
# Out:
# Index(['数学の点数', '国語の点数', '英語の点数'], dtype='object')

# %%
"""インデックスの定義
"""
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
"""特定列の取得
"""
df["数学の点数"]
# Out:
# 0     90
# 1     40
# 2     54
# 3     61
# 4     78
# 5     48
# 6     58
# 7     80
# 8     65
# 9     69
# 10    63
# 11    61
# 12    51
# 13    94
# 14    98
# 15    88
# 16    98
# 17    87
# 18    54
# 19    49
# 20    92
# 21    84
# 22    42
# 23    90
# 24    90
# 25    77
# 26    79
# 27    60
# 28    67
# 29    88
#       ..
# 70    91
# 71    64
# 72    80
# 73    66
# 74    91
# 75    85
# 76    70
# 77    50
# 78    94
# 79    84
# 80    76
# 81    57
# 82    40
# 83    41
# 84    95
# 85    43
# 86    90
# 87    56
# 88    70
# 89    88
# 90    68
# 91    94
# 92    60
# 93    99
# 94    79
# 95    67
# 96    55
# 97    87
# 98    51
# 99    52
# Name: 数学の点数, Length: 100, dtype: int32

# %%
"""特定行の取得
"""
df[1:10]
# Out:
#    数学の点数  国語の点数  英語の点数
# 1     40     92     40
# 2     54     61     93
# 3     61     99     70
# 4     78     97     56
# 5     48     74     59
# 6     58     71     51
# 7     80     67     84
# 8     65     62     90
# 9     69     60     88

# %%
"""特定行列の取得
loc：データの取得にインデックス名とカラム名を用いる
"""
df.loc[
    1:10,
    ["数学の点数","英語の点数"]
]
# Out:
#     数学の点数  英語の点数
# 1      40     40
# 2      54     93
# 3      61     70
# 4      78     56
# 5      48     59
# 6      58     51
# 7      80     84
# 8      65     90
# 9      69     88
# 10     63     86

# %%
"""特定行列の取得
iloc：データの取得にインデックス番号とカラム番号を用いる
"""
df.iloc[
    1:10,
    [0,1]
]
# Out:
#    数学の点数  国語の点数
# 1     40     92
# 2     54     61
# 3     61     99
# 4     78     97
# 5     48     74
# 6     58     71
# 7     80     67
# 8     65     62
# 9     69     60

# %%
"""条件で取得
"""
df[df.数学の点数>=90]
# Out:
#     数学の点数  国語の点数  英語の点数
# 0      90     42     88
# 13     94     60     55
# 14     98     82     42
# 16     98     78     46
# 20     92     73     47
# 23     90     67     50
# 24     90     94     52
# 30     96     90     93
# 38     94     99     48
# 43     94     88     88
# 56     97     60     69
# 60     91     58     74
# 65     93     72     66
# 67     91     71     67
# 70     91     53     86
# 74     91     47     59
# 78     94     74     60
# 84     95     77     78
# 86     90     89     93
# 91     94     45     49
# 93     99     49     82

# %%
"""条件で取得
特定列のみ
"""
df["国語の点数"][df.数学の点数>=90]
# Out:
# 0     42
# 13    60
# 14    82
# 16    78
# 20    73
# 23    67
# 24    94
# 30    90
# 38    99
# 43    88
# 56    60
# 60    58
# 65    72
# 67    71
# 70    53
# 74    47
# 78    74
# 84    77
# 86    89
# 91    45
# 93    49
# Name: 国語の点数, dtype: int32

# %% [markdown]
# # DFの追加と削除

# %% [markdown]
# ## 行の追加

# %%
"""行の追加
"""
df1 = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(5)),
    "国語の点数":np.random.randint(40,100,(5)),
    "英語の点数":np.random.randint(40,100,(5)),
})
df1
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     42     76     49
# 1     69     84     64
# 2     60     56     91
# 3     79     66     40
# 4     63     77     93

# %%
df2 = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(1)),
    "国語の点数":np.random.randint(40,100,(1)),
    "英語の点数":np.random.randint(40,100,(1)),
})
df2
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     71     51     62

# %%
df=df1.append(df2)
df
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     42     76     49
# 1     69     84     64
# 2     60     56     91
# 3     79     66     40
# 4     63     77     93
# 0     71     51     62

# %%
df=pd.concat([df1,df2])
df
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     42     76     49
# 1     69     84     64
# 2     60     56     91
# 3     79     66     40
# 4     63     77     93
# 0     71     51     62

# %% [markdown]
# ## 列の追加

# %%
"""列の追加
"""
df1 = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(5)),
    "国語の点数":np.random.randint(40,100,(5)),
    "英語の点数":np.random.randint(40,100,(5)),
})
df1
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     79     42     62
# 1     83     58     71
# 2     80     78     50
# 3     97     88     81
# 4     84     81     73

# %%
df2 = pd.DataFrame({
    "理科の点数":np.random.randint(40,100,(5)),
})
df2
# Out:
#    理科の点数
# 0     87
# 1     96
# 2     56
# 3     42
# 4     79

# %%
df1["理科の点数"]=df2
df1
# Out:
#    数学の点数  国語の点数  英語の点数  理科の点数
# 0     79     42     62     87
# 1     83     58     71     96
# 2     80     78     50     56
# 3     97     88     81     42
# 4     84     81     73     79

# %%
df3 = pd.DataFrame({
    "社会の点数":np.random.randint(40,100,(5)),
})
df3
# Out:
#    社会の点数
# 0     70
# 1     41
# 2     71
# 3     97
# 4     61

# %%
df=pd.concat([df1,df3],axis=1)
df
# Out:
#    数学の点数  国語の点数  英語の点数  理科の点数  社会の点数
# 0     79     42     62     87     70
# 1     83     58     71     96     41
# 2     80     78     50     56     71
# 3     97     88     81     42     97
# 4     84     81     73     79     61

# %% [markdown]
# ## 行列の削除

# %%
df = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(5)),
    "国語の点数":np.random.randint(40,100,(5)),
    "英語の点数":np.random.randint(40,100,(5)),
})
df
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     59     45     79
# 1     62     84     49
# 2     97     41     56
# 3     91     43     56
# 4     88     48     57

# %%
"""行の削除"""
df=df.drop(1)
df
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     59     45     79
# 2     97     41     56
# 3     91     43     56
# 4     88     48     57

# %%
"""列の削除
"""
del df["数学の点数"]
df
# Out:
#    国語の点数  英語の点数
# 0     45     79
# 2     41     56
# 3     43     56
# 4     48     57

# %% [markdown]
# # ファイルへの読み書き
# csvデータをpandasのデータフレームとして扱うことができます

# %%
"""読み込み
"""
df=pd.read_csv("./data/test_read.csv",engine='python',encoding='utf8')
df
# Out:
#      姓    名
# 0  明石家  サンマ
# 1  ビート  たけし
# 2   島田   紳助

# %%
"""1行目をヘッダーとして扱わない
"""
df=pd.read_csv("./data/test_read.csv",engine='python',header=None,encoding='utf8')
df
# Out:
#      0    1
# 0    姓    名
# 1  明石家  サンマ
# 2  ビート  たけし
# 3   島田   紳助

# %%
"""書き込み
"""
df = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(50)),
    "国語の点数":np.random.randint(40,100,(50)),
    "英語の点数":np.random.randint(40,100,(50)),
})
df.to_csv("./data/test_write.csv",encoding='utf8')

# %% [markdown]
# ## DFの応用
# 便利な使い方を紹介します

# %%
df = pd.DataFrame({
    "数学の点数":np.random.randint(40,100,(5)),
    "国語の点数":np.random.randint(40,100,(5)),
    "英語の点数":np.random.randint(40,100,(5)),
})
df
# Out:
#    数学の点数  国語の点数  英語の点数
# 0     59     75     85
# 1     69     58     81
# 2     48     75     53
# 3     81     98     77
# 4     99     80     66

# %% [markdown]
# ### 統計量

# %%
"""それぞれの列の最小値を取得
"""
df.agg("min")
# Out:
# 数学の点数    48
# 国語の点数    58
# 英語の点数    53
# dtype: int32

# %%
"""それぞれの列の統計量を取得
"""
df.agg(["min","max","sum","mean","median","std"])
# Out:
#              数学の点数       国語の点数       英語の点数
# min      48.000000   58.000000   53.000000
# max      99.000000   98.000000   85.000000
# sum     356.000000  386.000000  362.000000
# mean     71.200000   77.200000   72.400000
# median   69.000000   75.000000   77.000000
# std      19.753481   14.307341   12.953764

# %% [markdown]
# ### 結合
#
# inner join
#
# left join
#
# right join
#
# を行う。

# %%
df1 = pd.DataFrame(
    {
        'A': ['A0', 'A1', 'A2', 'A3'],
        'B': ['B0', 'B1', 'B2', 'B3'],
        'C': ['C0', 'C1', 'C2', 'C3'],
        'D': ['D0', 'D1', 'D2', 'D3']
    },index=[0, 1, 2, 3]
)
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame(
    {
        'B': ['B2', 'B3', 'B6', 'B7'],
        'D': ['D2', 'D3', 'D6', 'D7'],
        'F': ['F2', 'F3', 'F6', 'F7']
    },index=[2, 3, 6, 7]
)
df2
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
"""inner join
"""
pd.merge(df1, df2, on='B')
# Out:
#     A   B   C D_x D_y   F
# 0  A2  B2  C2  D2  D2  F2
# 1  A3  B3  C3  D3  D3  F3

# %%
"""left join
"""
pd.merge(df1, df2,how="left", on='B')
# Out:
#     A   B   C D_x  D_y    F
# 0  A0  B0  C0  D0  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN
# 2  A2  B2  C2  D2   D2   F2
# 3  A3  B3  C3  D3   D3   F3

# %%
"""right join
"""
pd.merge(df1, df2,how="right", on='B')
# Out:
#      A   B    C  D_x D_y   F
# 0   A2  B2   C2   D2  D2  F2
# 1   A3  B3   C3   D3  D3  F3
# 2  NaN  B6  NaN  NaN  D6  F6
# 3  NaN  B7  NaN  NaN  D7  F7

# %% [markdown]
# ### groupby
#
# 特定の列をグループ化させます

# %%
df = pd.DataFrame(
    {
        'sex': ['man', 'man', 'wooman', 'wooman', 'man', 'man', 'wooman'],
        'height': [170,175,155,149,160,165,170],
        'weight': [70,70,50,55,55,60,56],
    }
)
df
# Out:
#       sex  height  weight
# 0     man     170      70
# 1     man     175      70
# 2  wooman     155      50
# 3  wooman     149      55
# 4     man     160      55
# 5     man     165      60
# 6  wooman     170      56

# %%
"""性別でグループ化し、height/weightの平均値を求める
"""
df.groupby('sex').mean()
# Out:
#         height     weight
# sex
# man      167.5  63.750000
# wooman   158.0  53.666667

# %%
"""性別でグループ化し、height/weightの統計量を求める
"""
df.groupby('sex').agg(["min","max","sum","mean","median","std"])
# Out:
#        height                                    weight                      \
#           min  max  sum   mean median        std    min max  sum       mean
# sex
# man       160  175  670  167.5  167.5   6.454972     55  70  255  63.750000
# wooman    149  170  474  158.0  155.0  10.816654     50  56  161  53.666667
#
#
#        median      std
# sex
# man        65  7.50000
# wooman     55  3.21455

# %% [markdown]
# # Series
# ここまでは、DFについてみてきましたが、pandasのデータ構造には、Seriesというものがあります
#
# これは「DFの任意の列」と解釈されます

# %%
"""Seriesの生成
"""
s = pd.Series([60, 55, 90, 99, 73], index=['Aさん', 'Bさん', 'Cさん', 'Dさん', 'Eさん'])
s
# Out:
# Aさん    60
# Bさん    55
# Cさん    90
# Dさん    99
# Eさん    73
# dtype: int64

# %%
"""Seriesの生成+Name
"""
s = pd.Series([60, 55, 90, 99, 73], index=['Aさん', 'Bさん', 'Cさん', 'Dさん', 'Eさん'],name="算数の点数")
s
# Out:
# Aさん    60
# Bさん    55
# Cさん    90
# Dさん    99
# Eさん    73
# Name: 算数の点数, dtype: int64

# %%
"""データ取得
"""
print(s["Aさん"])
# Out:
# 60

# %%
"""データ追加
"""
s_add = pd.Series({'Fさん': 100})
s_new=s.append(s_add)
s_new
# Out:
# Aさん     60
# Bさん     55
# Cさん     90
# Dさん     99
# Eさん     73
# Fさん    100
# dtype: int64

# %%
"""行の追加
"""
s_new=pd.concat([s,s_add])
s_new
# Out:
# Aさん     60
# Bさん     55
# Cさん     90
# Dさん     99
# Eさん     73
# Fさん    100
# dtype: int64

# %%
"""列の追加
"""
s1 = pd.Series([60, 55, 90, 99, 73], index=['Aさん', 'Bさん', 'Cさん', 'Dさん', 'Eさん'],name="算数の点数")
s2 = pd.Series([65, 59, 60, 90, 83], index=['Aさん', 'Bさん', 'Cさん', 'Dさん', 'Eさん'],name="国語の点数")

s=pd.concat([s1,s2],axis=1)
s
# Out:
#      算数の点数  国語の点数
# Aさん     60     65
# Bさん     55     59
# Cさん     90     60
# Dさん     99     90
# Eさん     73     83

# %% [markdown]
# つまり、Pandasでは
#
# + Series：１次元
# + DataFrame：２次元
